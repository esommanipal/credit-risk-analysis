# %%
import pandas as pd

df = pd.read_csv('/Users/josephtoniodavid/Documents/credit-risk-analysis/raw_cr_loan2.csv')

df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
print(df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32576    False
# 32577    False
# 32578    False
# 32579    False
# 32580    False
# Length: 32416, dtype: bool

# %%
print(df.corr())
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.173293           0.163001
# person_income                 0.173293       1.000000           0.133903
# person_emp_length             0.163001       0.133903           1.000000
# loan_amnt                     0.050680       0.265947           0.113183
# loan_int_rate                 0.011760       0.000878          -0.056607
# loan_status                  -0.022698      -0.145005          -0.082817
# loan_percent_income          -0.042300      -0.254472          -0.053999
# cb_person_cred_hist_length    0.859215       0.117614           0.144889
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.050680       0.011760    -0.022698
# person_income                0.265947       0.000878    -0.145005
# person_emp_length            0.113183      -0.056607    -0.082817
# ...

# %%
for x in df.index:
  if df.loc[x, "person_emp_length"] > 120 or df.loc[x, "person_age"] > 120:
    df.drop(x, inplace = True)

# %%
x = df["loan_amnt"].mode()
x
# Out:
# 0    10000
# Name: loan_amnt, dtype: int64
